# %% [markdown]
# # basic level

# %% [markdown]
# # Retrieve the names of employees who earn more than the average salary of all employees
# ![Screenshot 2026-01-17 150609.png](data:image/png;base64,...)

# %% [markdown]
# # Q2 Find the employees who belong to the department with the highest average salary.
# ![Screenshot 2026-01-17 151048.png](data:image/png;base64,...)

# %% [markdown]
# # Q3 List all employees who have made at least one sale
# ![Screenshot 2026-01-17 151318.png](data:image/png;base64,...)

# %% [markdown]
# # Q4 Find the employee with the highest sale amount
#
# ![Screenshot 2026-01-17 151845.png](data:image/png;base64,...)

# %% [markdown]
# # Q5 Retrieve the names of employees whose salaries are higher than Shubham’s salary.
# ![Screenshot 2026-01-17 152039.png](data:image/png;base64,...)

# %% [markdown]
# # INTERMEDIATE QUESTION

# %% [markdown]
# # 1. Find employees who work in the same department as Abhishek
# ![Screenshot 2026-01-17 153620.png](data:image/png;base64,...)

# %% [markdown]
# # List departments that have at least one employee earning more than ₹60,000
# ![Screenshot 2026-01-17 154359.png](data:image/png;base64,...)

# %% [markdown]
# # 3 Find the department name of the employee who made the highest sale
# ![Screenshot 2026-01-17 154545.png](data:image/png;base64,...)

# %% [markdown]
# # 4. Retrieve employees who have made sales greater than the average sale amount.
#
# ![Screenshot 2026-01-17 154738.png](data:image/png;base64,...)

# %% [markdown]
# # 5 Find the total sales made by employees who earn more than the average salary
# ![Screenshot 2026-01-17 155012.png](data:image/png;base64,...)

# %% [markdown]
# # ADVANCED LVL

# %% [markdown]
# # 1 Find employees who have not made any sales.
# ![Screenshot 2026-01-17 155832.png](data:image/png;base64,...)

# %% [markdown]
# # Q2 List departments where the average salary is above ₹55,000.
# ![Screenshot 2026-01-17 160039.png](data:image/png;base64,...)

# %% [markdown]
# # Q3 Retrieve department names where the total sales exceed ₹10,000
# .
# ![Screenshot 2026-01-17 160143.png](data:image/png;base64,...)

# %% [markdown]
# # Q4 Find the employee who has made the second-highest sale.
# ![Screenshot 2026-01-17 160436.png](data:image/png;base64,...)

# %% [markdown]
# # Q5 Retrieve the names of employees whose salary is greater than the highest sale amount recorded
# ![Screenshot 2026-01-17 160616.png](data:image/png;base64,...)
